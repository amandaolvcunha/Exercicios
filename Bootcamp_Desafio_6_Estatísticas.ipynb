# %% [markdown]
# <a href="https://colab.research.google.com/github/amandaolvcunha/Exercicios/blob/main/Bootcamp_Desafio_6_Estat%C3%ADsticas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div>
#     <p style="float: right;"><img src="https://media.swipepages.com/2021/2/sirius-logo-principal-tag-1-300.png" height="80px"border="1px"></p>
#
# </div>
# <h1>Nano Desafio 6 </h1>
# <h2>Pandas - estatísticas </h2>
#
# Aluno: Amanda Oliveira Cunha
#
# Data: 22/01/2024

# %% [markdown]
# ##### Introdução

# %% [markdown]
# Já conhecemos o pandas e um pouco do seu poder para analisar dados! Agora vamos fazer alguns calculos estatísticos usando essa ferramenta já no ritmo de despedida e também como uma  prévia do que esta por vir. Afinal você está crescendo e sua jornada de Introdução ao Python está chegando ao fim!!!
#
# A Estatística já está batendo a porta e dando boas vindas!!

# %% [markdown]
# ##### Estatísticas
# Estatísticas resumo, para que servem? Adivinhe? - elas "resumem" muitos números!!!. Por exemplo, média, mediana, mínimo, máximo e desvio padrão são estatísticas resumidas. O cálculo de estatísticas resumidas permitem que você tenha uma noção melhor de seus dados, mesmo que você tenha milhares ou milhões!!

# %% [markdown]
# ##### O conjunto de dados
# A Walt Disney Studios já produziu mais de 600 filmes desde seu filme de estreia, Branca de Neve e os Sete Anões, em 1937. Vamos, explorar um conjunto de dados de filmes da Disney !! Esses dados foram compilados por <a href="https://data.world/kgarrett/disney-character-success-00-16">Kelly Garrett</a>. Os dados contêm 579 filmes da Disney com seis características: título do filme, data de lançamento, gênero, classificação MPAA, bilheteria bruta  e bilheteria ajustada pela inflação. </p>

# %% [markdown]
# 1 -Importe o  [dataset disney_movies_total_gross.csv](https://drive.google.com/file/d/1WtNcv-0XV5j954UNDkf2GW60vZHpqpzl/view?usp=sharing) e salvar com o nome dados.

# %%
import pandas as pd

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 df_disney = pd.read_csv('/content/drive/MyDrive/MBT/Arquivos de atividades/Nano Desafio Estatística/disney_movies_total_gross.csv', delimiter = ',')

# %% [markdown]
# 2 -  Imprima as primeiras linhas desse dataset

# %%
df_disney.head()
# Out:
#                        movie_title release_date      genre mpaa_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross
# 0    184925485                5228953251
# 1     84300000                2188229052
# 2     83320000                2187090808
# 3     65000000                1078510579
# 4     85000000                 920608730

# %% [markdown]
# Obs.: Motion Picture Association of America (MPAA) - é uma associação que tem por objetivo original garantir a viabilidade da indústria cinematográfica norte-americana. Além disso, a MPA estabeleceu diretrizes para o conteúdo de filmes que resultaram na criação do Código de Produção em 1930.
# Por exemplo, a classificação de filmes segundo essa associação é:

# %% [markdown]
# ![wikipedia](mpaa_rating.png)
#
# fonte:https://pt.wikipedia.org/wiki/Motion_Picture_Association

# %% [markdown]
# Agora, antes de mais nada vamos renomear as colunas para ficar mais fácil o entendimento?

# %% [markdown]
# ['tit_do_filme','dt_lancamento','genero','classificacao_mpaa','bilheteria_bruta','bilheteria_ajustada_inflacao']

# %%
df_disney.rename(columns = {'movie_title': 'tit_do_filme', 'release_date':'dt_lancamento','genre':'genero','mpaa_rating':'classificacao_mpaa','total_gross':'bilheteria_bruta','inflation_adjusted_gross':'bilheteria_ajustada_inflacao'}, inplace = True)

# %% [markdown]
# 3 - Veja o dataset agora:

# %%
df_disney.head()
# Out:
#                       tit_do_filme dt_lancamento     genero  \
# 0  Snow White and the Seven Dwarfs    1937-12-21    Musical
# 1                        Pinocchio    1940-02-09  Adventure
# 2                         Fantasia    1940-11-13    Musical
# 3                Song of the South    1946-11-12  Adventure
# 4                       Cinderella    1950-02-15      Drama
#
#   classificacao_mpaa  bilheteria_bruta  bilheteria_ajustada_inflacao
# 0                  G         184925485                    5228953251
# 1                  G          84300000                    2188229052
# 2                  G          83320000                    2187090808
# 3                  G          65000000                    1078510579
# 4                  G          85000000                     920608730

# %% [markdown]
# 4 -Imprima informações básicas sobre o DataFrame

# %%
df_disney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tit_do_filme                  579 non-null    object
#  1   dt_lancamento                 579 non-null    object
#  2   genero                        562 non-null    object
#  3   classificacao_mpaa            523 non-null    object
#  4   bilheteria_bruta              579 non-null    int64
#  5   bilheteria_ajustada_inflacao  579 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 27.3+ KB

# %% [markdown]
# 5 - Calcule a média da bilheteria ajustada

# %%
df_disney['bilheteria_ajustada_inflacao'].mean().round(2)
# Out:
# 118762523.31

# %% [markdown]
# 6 - Calcule a mediana da bilheterias ajustada

# %%
df_disney['bilheteria_ajustada_inflacao'].median().round(2)
# Out:
# 55159783.0

# %% [markdown]
# 7 - Encontre as datas máximas e minimas de lançamentos de filmes nesse dataset

# %%
print('Data Máxima: {}'.format(pd.to_datetime(df_disney['dt_lancamento']).max()))

print('Data Mínima: {}'.format(pd.to_datetime(df_disney['dt_lancamento']).min()))
# Out:
# Data Máxima: 2016-12-16 00:00:00
# Data Mínima: 1937-12-21 00:00:00

# %% [markdown]
# 8 - Qual filme tem maior bilheteria_ajustada_inflacao ?

# %%
filme_maior_bilheteria = df_disney.loc[df_disney['bilheteria_ajustada_inflacao'].idxmax()]

print('O filme de maior bilheteria ajudata é {}'. format(filme_maior_bilheteria['tit_do_filme']))
# Out:
# O filme de maior bilheteria ajudata é Snow White and the Seven Dwarfs

# %% [markdown]
# 9 - Ordene os dados por dt_lancamento e chame de data_ordenada

# %%
data_ordenada = df_disney.sort_values(['dt_lancamento'])

data_ordenada.head()
# Out:
#                       tit_do_filme dt_lancamento     genero  \
# 0  Snow White and the Seven Dwarfs    1937-12-21    Musical
# 1                        Pinocchio    1940-02-09  Adventure
# 2                         Fantasia    1940-11-13    Musical
# 3                Song of the South    1946-11-12  Adventure
# 4                       Cinderella    1950-02-15      Drama
#
#   classificacao_mpaa  bilheteria_bruta  bilheteria_ajustada_inflacao
# 0                  G         184925485                    5228953251
# 1                  G          84300000                    2188229052
# 2                  G          83320000                    2187090808
# 3                  G          65000000                    1078510579
# 4                  G          85000000                     920608730

# %% [markdown]
# 10- Obtenha a soma cumulativa da bilheteria_ajustada_inflacao,adicione ao dataset com o nome de bilheteria_milionaria

# %%
data_ordenada['bilheteria_milionaria'] = data_ordenada['bilheteria_ajustada_inflacao'].cumsum()

data_ordenada.head()
# Out:
#                       tit_do_filme dt_lancamento     genero  \
# 0  Snow White and the Seven Dwarfs    1937-12-21    Musical
# 1                        Pinocchio    1940-02-09  Adventure
# 2                         Fantasia    1940-11-13    Musical
# 3                Song of the South    1946-11-12  Adventure
# 4                       Cinderella    1950-02-15      Drama
#
#   classificacao_mpaa  bilheteria_bruta  bilheteria_ajustada_inflacao  \
# 0                  G         184925485                    5228953251
# 1                  G          84300000                    2188229052
# 2                  G          83320000                    2187090808
# 3                  G          65000000                    1078510579
# 4                  G          85000000                     920608730
#
#    bilheteria_milionaria
# 0             5228953251
# 1             7417182303
# 2             9604273111
# 3            10682783690
# 4            11603392420

# %% [markdown]
# 11 - Veja a coluna que você criou

# %%
data_ordenada.head()
# Out:
#                       tit_do_filme dt_lancamento     genero  \
# 0  Snow White and the Seven Dwarfs    1937-12-21    Musical
# 1                        Pinocchio    1940-02-09  Adventure
# 2                         Fantasia    1940-11-13    Musical
# 3                Song of the South    1946-11-12  Adventure
# 4                       Cinderella    1950-02-15      Drama
#
#   classificacao_mpaa  bilheteria_bruta  bilheteria_ajustada_inflacao  \
# 0                  G         184925485                    5228953251
# 1                  G          84300000                    2188229052
# 2                  G          83320000                    2187090808
# 3                  G          65000000                    1078510579
# 4                  G          85000000                     920608730
#
#    bilheteria_milionaria
# 0             5228953251
# 1             7417182303
# 2             9604273111
# 3            10682783690
# 4            11603392420

# %% [markdown]
# 12 - Selecione os filmes de aventura e atribua a uma variável chamada filmes_aventura

# %%
filmes_aventura = df_disney.loc[df_disney['genero'] == 'Adventure']

# %% [markdown]
# 13 - Veja as primeiras linha desse novo dataset:

# %%
filmes_aventura.head()
# Out:
#                     tit_do_filme dt_lancamento     genero classificacao_mpaa  \
# 1                      Pinocchio    1940-02-09  Adventure                  G
# 3              Song of the South    1946-11-12  Adventure                  G
# 5   20,000 Leagues Under the Sea    1954-12-23  Adventure                NaN
# 12        The Sword in the Stone    1963-12-25  Adventure                NaN
# 21                  The Rescuers    1977-06-22  Adventure                NaN
#
#     bilheteria_bruta  bilheteria_ajustada_inflacao
# 1           84300000                    2188229052
# 3           65000000                    1078510579
# 5           28200000                     528279994
# 12          22182353                     153870834
# 21          48775599                     159743914

# %% [markdown]
# 14 - Conte o número de filmes por genero e ordene

# %%
df_genero_2 = df_disney['genero'].value_counts()
df_genero_2 = pd.DataFrame(df_genero_2)

df_genero_2.sort_values(['genero'], inplace = True)

df_genero_2
# Out:
#                      genero
# Concert/Performance       2
# Black Comedy              3
# Horror                    6
# Western                   7
# Musical                  16
# Documentary              16
# Romantic Comedy          23
# Thriller/Suspense        24
# Action                   40
# Drama                   114
# Adventure               129
# Comedy                  182

# %% [markdown]
# 15 - Calcule agora a proporção de filmes por genero e ordene

# %%
df_genero_2['%'] = df_disney['genero'].value_counts(normalize = True)*100
df_genero_2
# Out:
#                      genero          %
# Concert/Performance       2   0.355872
# Black Comedy              3   0.533808
# Horror                    6   1.067616
# Western                   7   1.245552
# Musical                  16   2.846975
# Documentary              16   2.846975
# Romantic Comedy          23   4.092527
# Thriller/Suspense        24   4.270463
# Action                   40   7.117438
# Drama                   114  20.284698
# Adventure               129  22.953737
# Comedy                  182  32.384342

# %% [markdown]
# Estatísticas resumidas agrupadas

# %% [markdown]
# 16 - Calcule o total da "bilheteria_bruta"

# %%
df_disney['bilheteria_bruta'].sum()
# Out:
# 37462335553

# %% [markdown]
# 17 - Visualize os tipos de generos que tem nesse dataset:

# %%
set(df_disney['genero'])
# Out:
# {'Action',
#  'Adventure',
#  'Black Comedy',
#  'Comedy',
#  'Concert/Performance',
#  'Documentary',
#  'Drama',
#  'Horror',
#  'Musical',
#  'Romantic Comedy',
#  'Thriller/Suspense',
#  'Western',
#  nan}

# %% [markdown]
# 18 - Calcule o total da bilheteria_bruta pelo genero 'Drama'

# %%
df_genero_drama = df_disney.loc[df_disney['genero']=='Drama']

drama = df_genero_drama['bilheteria_bruta'].sum()
drama
# Out:
# 4106972970

# %% [markdown]
# 19 - Calcule o total da bilheteria_bruta pelo genero Comedia 'Comedy'

# %%
df_genero_comedy = df_disney.loc[df_disney['genero']=='Comedy']

comedy = df_genero_comedy['bilheteria_bruta'].sum()
comedy
# Out:
# 8119619678

# %% [markdown]
# 20 - Calcule o total da bilheteria_bruta pelo genero Ação 'Action'

# %%
df_genero_action = df_disney.loc[df_disney['genero']=='Action']

action = df_genero_action['bilheteria_bruta'].sum()
action
# Out:
# 4184563282

# %% [markdown]
# 21 -  Obtenha proporção do bilheteria_bruta para os três generos acima.

# %%
generos_selecionados= ['Action', 'Comedy','Drama']

df_generos_3 = df_disney[df_disney['genero'].isin(generos_selecionados)]

df_generos_3 = df_generos_3.groupby('genero')[['bilheteria_bruta']].sum()
df_generos_3 = pd.DataFrame(df_generos_3)
df_generos_3['%'] = df_generos_3['bilheteria_bruta'] / df_generos_3['bilheteria_bruta'].sum() *100

print('Proporção entre eles: {}'.format(df_generos_3))

prop_geral = [action, comedy, drama] / df_disney['bilheteria_bruta'].sum()

print('Proporção geral: {}'.format(prop_geral))
# Out:
# Proporção entre eles:         bilheteria_bruta          %
# genero
# Action        4184563282  25.498285
# Comedy        8119619678  49.476220
# Drama         4106972970  25.025495
# Proporção geral: [0.11170054 0.21674088 0.10962939]

# %% [markdown]
# 22 - Importe numpy com o alias np

# %%
import numpy as np

# %% [markdown]
# 23 - Para cada genero de filme, agregue a bilheteria_bruta obtendo min, max, média e mediana e imprima o resultado
#
# Dica: use numpy para as estatísticas

# %%
df_disney.groupby('genero')[['bilheteria_bruta']].agg([np.mean,np.median,np.max,np.min])
# Out:
#                     bilheteria_bruta
#                                 mean      median       amax      amin
# genero
# Action                  1.046141e+08  43315244.5  623279547         0
# Adventure               1.270471e+08  65000000.0  936662225      2815
# Black Comedy            3.251440e+07  28084357.0   52353636  17105219
# Comedy                  4.461329e+07  26923500.5  244082982     45779
# Concert/Performance     5.172823e+07  51728233.0   65281781  38174685
# Documentary             1.129285e+07   9688331.0   32011576     20521
# Drama                   3.602608e+07  19730097.0  201151353         0
# Horror                  1.451148e+07  13439137.5   26570463   4877567
# Musical                 7.233026e+07  53041787.5  218951625   5632086
# Romantic Comedy         5.009595e+07  32680633.0  178406268    468240
# Thriller/Suspense       5.861694e+07  28153827.0  293506292   2154540
# Western                 5.128735e+07  56932305.0   89302115   8247627

# %% [markdown]
# 24 - Para cada genero de filme, agregue bilheteria_bruta e bilheteria_ajustada_inflacao: obtenha o minimo, maximo, média e mediana

# %%
df_disney.groupby('genero')[['bilheteria_bruta','bilheteria_ajustada_inflacao']].agg([np.mean,np.median,np.max,np.min])
# Out:
#                     bilheteria_bruta                                   \
#                                 mean      median       amax      amin
# genero
# Action                  1.046141e+08  43315244.5  623279547         0
# Adventure               1.270471e+08  65000000.0  936662225      2815
# Black Comedy            3.251440e+07  28084357.0   52353636  17105219
# Comedy                  4.461329e+07  26923500.5  244082982     45779
# Concert/Performance     5.172823e+07  51728233.0   65281781  38174685
# Documentary             1.129285e+07   9688331.0   32011576     20521
# Drama                   3.602608e+07  19730097.0  201151353         0
# Horror                  1.451148e+07  13439137.5   26570463   4877567
# Musical                 7.233026e+07  53041787.5  218951625   5632086
# Romantic Comedy         5.009595e+07  32680633.0  178406268    468240
# Thriller/Suspense       5.861694e+07  28153827.0  293506292   2154540
# Western                 5.128735e+07  56932305.0   89302115   8247627
#
#                     bilheteria_ajustada_inflacao                           \
#                                             mean       median        amax
# genero
# Action                              1.374734e+08   69012064.5   660081224
# Adventure                           1.903974e+08  102254492.0  2188229052
# Black Comedy                        5.224349e+07   51579764.0    76758193
# Comedy                              8.466773e+07   51195217.0  1362870985
# Concert/Performance                 5.741084e+07   57410839.0    76646993
# Documentary                         1.271803e+07   12344483.5    35981010
# Drama                               7.189302e+07   39325794.0  1236035515
# Horror                              2.341385e+07   18589709.5    48546161
# Musical                             6.035979e+08  103167587.5  5228953251
# Romantic Comedy                     7.777708e+07   57925202.0   356389765
# Thriller/Suspense                   8.965379e+07   51804588.0   485424724
# Western                             7.381571e+07   89042541.0   115781734
#
#
#                          amin
# genero
# Action                      0
# Adventure                2984
# Black Comedy         28392518
# Comedy                  82277
# Concert/Performance  38174685
# Documentary             23064
# Drama                       0
# Horror                9907922
# Musical              11468231
# Romantic Comedy        907414
# Thriller/Suspense     3957025
# Western              15983331

# %% [markdown]
# Está na hora de fazermos um pouco de gráficos. Não existe análise de dados sem visualização!!

# %%
import seaborn as sns

# %% [markdown]
# 25 - Some a bilheteria_bruta por genero

# %%
df_bilheteria_genero = df_disney.groupby('genero')[['bilheteria_bruta']].sum()

df_bilheteria_genero
# Out:
#                      bilheteria_bruta
# genero
# Action                     4184563282
# Adventure                 16389069453
# Black Comedy                 97543212
# Comedy                     8119619678
# Concert/Performance         103456466
# Documentary                 180685619
# Drama                      4106972970
# Horror                       87068872
# Musical                    1157284155
# Romantic Comedy            1152206855
# Thriller/Suspense          1406806519
# Western                     359011459

# %% [markdown]
# 26 - Agora sim faça um gráfico de barras com o resultado anterior!

# %%
df_bilheteria_genero.plot(kind='barh')
# Out:
# <Axes: ylabel='genero'>

# %% [markdown]
# 27 - Importe o seaborn com o apelido sns

# %%
import seaborn as sns
sns.set()

# %% [markdown]
# 28 -Faça um boxplot comparando a bilheteria_ajustada_inflacao dos filmes de ação e comédia

# %%
generos_selecionados= ['Action', 'Comedy']

df_generos_4 = df_disney[df_disney['genero'].isin(generos_selecionados)]

sns.boxplot(y='bilheteria_ajustada_inflacao', x='genero', data = df_generos_4)
# Out:
# <Axes: xlabel='genero', ylabel='bilheteria_ajustada_inflacao'>

# %%
print('Esse documento foi modificado')
# Out:
# Esse documento foi modificado
